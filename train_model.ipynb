# %% [markdown]
# # House Price Trend Analysis Model Training
#
# This notebook trains a single XGBoost pipeline on the Delhi and Hyderabad datasets.
# It standardizes the city-specific columns, creates the `Price_per_Sqft` land value feature,
# fits the model, and saves the final pipeline as `model.pkl`.

# %%
from train_model import train_and_save_model

artifacts = train_and_save_model()
artifacts["metrics"]

# %%
artifacts["data"].head()
